# %%
import shutil
import os

# List of file paths to be copied
file_paths = [
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_0degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_100degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_105degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_10degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_110degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_115degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_120degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_125degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_130degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_135degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_140degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_145degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_150degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_155degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_15degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_160degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_165degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_170degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_175degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_180degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_185degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_190degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_195degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_200degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_205degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_20degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_210degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_215degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_225degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_270degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_275degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_280degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_285degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_290degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_295degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_300degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_305degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_310degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_315degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_320degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_325degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_330degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_335degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_340degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_345degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_350degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_355degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_5degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_60degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_75degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_80degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_85degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_90degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_95degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_0degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_100degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_105degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_10degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_110degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_115degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_120degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_125degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_130degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_135degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_140degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_145degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_150degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_155degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_15degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_160degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_165degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_170degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_175degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_180degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_185degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_190degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_195degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_200degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_205degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_20degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_210degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_215degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_225degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_270degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_275degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_280degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_285degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_290degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_295degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_300degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_305degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_310degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_315degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_320degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_325degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_330degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_335degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_340degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_345degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_350degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_355degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_5degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_60degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_75degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_80degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_85degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_90degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_95degree.png'
]

# Destination directory where files should be copied
destination_dir = r'C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp'

# Ensure destination directory exists
os.makedirs(destination_dir, exist_ok=True)

# Copy each file from source to destination
for file_path in file_paths:
    if os.path.isfile(file_path):
        file_name = os.path.basename(file_path)
        destination_path = os.path.join(destination_dir, file_name)
        shutil.copy(file_path, destination_path)
        print(f'Copied {file_name} to {destination_dir}')
    else:
        print(f'File not found: {file_path}')

print('All files processed successfully!')
# Out:
# Copied obj10_0degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_100degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_105degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_10degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_110degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_115degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_120degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_125degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_130degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_135degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_140degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_145degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# Copied obj10_150degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp
# ...

# %%
import shutil
import os

# Updated list of file paths to be copied
file_paths = [
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_0degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_100degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_105degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_10degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_110degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_115degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_120degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_125degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_130degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_135degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_140degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_145degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_150degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_155degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_15degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_160degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_165degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_170degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_175degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_180degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_185degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_190degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_195degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_200degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_205degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_20degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_210degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_215degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_225degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_270degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_275degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_280degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_285degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_290degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_295degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_300degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_305degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_310degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_315degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_320degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_325degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_330degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_335degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_340degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_345degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_350degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_355degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_5degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_60degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_75degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_80degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_85degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_90degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_95degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_0degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_100degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_105degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_10degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_110degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_115degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_120degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_125degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_130degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_135degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_140degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_145degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_150degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_155degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_15degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_160degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_165degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_170degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_175degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_180degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_185degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_190degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_195degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_200degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_205degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_20degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_210degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_215degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_225degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_230degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_235degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_240degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_245degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_250degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_255degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_260degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_30degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_35degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_40degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_45degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_50degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_55degree.png',
    r'C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_65degree.png'
]

# Destination directory where files should be copied
destination_dir = r'C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2'

# Ensure destination directory exists
os.makedirs(destination_dir, exist_ok=True)

# Copy each file from source to destination
for file_path in file_paths:
    if os.path.isfile(file_path):
        file_name = os.path.basename(file_path)
        destination_path = os.path.join(destination_dir, file_name)
        shutil.copy(file_path, destination_path)
        print(f'Copied {file_name} to {destination_dir}')
    else:
        print(f'File not found: {file_path}')

print('All files processed successfully!')
# Out:
# Copied obj10_0degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2
# Copied obj10_100degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2
# Copied obj10_105degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2
# Copied obj10_10degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2
# Copied obj10_110degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2
# Copied obj10_115degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2
# Copied obj10_120degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2
# Copied obj10_125degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2
# Copied obj10_130degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2
# Copied obj10_135degree.png to C:\Users\Asus\Desktop\COIL\coil-20\cars_lbp\cars_lbp_cluster2
# ...

# %%
import os
import shutil

# List of files to move
files_to_move = [
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_0degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_100degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_105degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_10degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_110degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_115degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_120degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_125degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_130degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_135degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_140degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_145degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_150degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_155degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_15degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_160degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_165degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_170degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_175degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_180degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_185degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_190degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_195degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_200degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_205degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_20degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_210degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_225degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_280degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_285degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_290degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_295degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_300degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_305degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_310degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_315degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_320degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_325degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_330degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_335degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_340degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_345degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_350degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_355degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_5degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_60degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_80degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_85degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_90degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_95degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_0degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_100degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_105degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_10degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_110degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_115degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_120degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_125degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_130degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_135degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_140degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_145degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_150degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_155degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_15degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_160degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_165degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_170degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_175degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_180degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_185degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_190degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_195degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_200degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_205degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_20degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_210degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_225degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_280degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_285degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_290degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_295degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_300degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_305degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_310degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_315degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_320degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_325degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_330degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_335degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_340degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_345degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_350degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_355degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_5degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_60degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_80degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_85degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_90degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_95degree.png"
]

# Target directory
target_dir = r"C:\Users\Asus\Desktop\COIL\coil-20\cars_hog\cars_hog_cluster1"

# Move the specified files
for file_path in files_to_move:
    if os.path.exists(file_path):
        file_name = os.path.basename(file_path)
        new_file_path = os.path.join(target_dir, file_name)
        try:
            shutil.move(file_path, new_file_path)
            print(f"Moved: {file_path} -> {new_file_path}")
        except Exception as e:
            print(f"Failed to move {file_path} to {new_file_path}: {e}")
    else:
        print(f"File not found: {file_path}")

print("File move operation complete.")
# Out:
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_0degree.png
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_100degree.png
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_105degree.png
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_10degree.png
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_110degree.png
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_115degree.png
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_120degree.png
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_125degree.png
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_130degree.png
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_135degree.png
# File not found: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_140degree.png
# ...

# %%
import os
import shutil

# List of files to move
files_to_move = [
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_215degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_220degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_230degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_235degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_240degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_245degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_250degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_255degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_25degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_260degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_265degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_270degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_275degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_30degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_35degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_40degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_45degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_50degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_55degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_65degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_70degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_75degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_220degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_230degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_235degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_240degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_245degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_250degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_255degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_25degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_260degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_265degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_270degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_275degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_30degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_35degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_40degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_45degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_50degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_55degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_65degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_70degree.png",
    r"C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj14_75degree.png"
]

# Target directory
target_dir = r"C:\Users\Asus\Desktop\COIL\coil-20\cars_hog\cars_hog_cluster2"

# Move the specified files
for file_path in files_to_move:
    if os.path.exists(file_path):
        file_name = os.path.basename(file_path)
        new_file_path = os.path.join(target_dir, file_name)
        try:
            shutil.move(file_path, new_file_path)
            print(f"Moved: {file_path} -> {new_file_path}")
        except Exception as e:
            print(f"Failed to move {file_path} to {new_file_path}: {e}")
    else:
        print(f"File not found: {file_path}")

print("File move operation complete.")
# Out:
# Moved: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_215degree.png -> C:\Users\Asus\Desktop\COIL\coil-20\cars_hog\cars_hog_cluster2\obj10_215degree.png
# Moved: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_220degree.png -> C:\Users\Asus\Desktop\COIL\coil-20\cars_hog\cars_hog_cluster2\obj10_220degree.png
# Moved: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_230degree.png -> C:\Users\Asus\Desktop\COIL\coil-20\cars_hog\cars_hog_cluster2\obj10_230degree.png
# Moved: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_235degree.png -> C:\Users\Asus\Desktop\COIL\coil-20\cars_hog\cars_hog_cluster2\obj10_235degree.png
# Moved: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_240degree.png -> C:\Users\Asus\Desktop\COIL\coil-20\cars_hog\cars_hog_cluster2\obj10_240degree.png
# Moved: C:\Users\Asus\Desktop\COIL\coil-20\coil20_cars_\obj10_245degree.png -> C:\Users\Asus\Desktop\COIL\coil-20\cars_hog\cars_hog_cluster2\obj10_245degree.png
# ...
